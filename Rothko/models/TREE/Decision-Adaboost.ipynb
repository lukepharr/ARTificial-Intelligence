# %% [markdown]
# # Decision Tree Model for Rothko Art

# %%
from sklearn import tree
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import graphviz 
import pydotplus
import sklearn
import pickle

# For AdaBoost
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ## Load art data

# %%
data = pd.DataFrame.from_csv('../../data/data.csv')
# Out:
# /Users/acanois/anaconda2/envs/lab/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   if __name__ == '__main__':

# %%
data = data[['year','shannon_entropy','mean_color_r','luminance','contrast', 'contour']]

# %%
# Bin the data into appropriate art timelines for the artist
bins = [1935, 1940, 1947, 1950, 1968, 1971]
data['year_bin']=pd.cut(data['year'], bins)

# %%
data.head()
# Out:
#    year  shannon_entropy  mean_color_r   luminance  contrast   contour  \
# 0  1946         6.768127    195.046332  181.738624  0.827169  0.000056
# 1  1953         6.937948    228.983463  161.723046  0.587802  0.000000
# 2  1944         6.519651    217.905564  214.564295  0.853499  0.003758
# 3  1951         6.451747    191.229599  184.080065  0.706196  0.000063
# 4  1949         5.738259    230.154804  224.799111  0.658131  0.000000
#
#        year_bin
# 0  (1940, 1947]
# 1  (1950, 1968]
# 2  (1940, 1947]
# 3  (1950, 1968]
# 4  (1947, 1950]

# %% [markdown]
# ## Create the model

# %%
# Create the Decision Tree Classifier
clf = tree.DecisionTreeClassifier()

# %%
# Split the columns to separate the features from the result/target data
features = data[['shannon_entropy','mean_color_r','luminance','contrast', 'contour']]
target = data['year_bin'].astype(str)

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features, target, random_state=41)

# %%
# Train the model
clf.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Plot the Decicion Tree
dot_data = tree.export_graphviz(
   clf, out_file=None,
   feature_names=['shannon_entropy','mean_color_r','luminance','contrast', 'contour'],  
   class_names=list(target.unique()),  
   filled=True, rounded=True,  
   special_characters=True)  

# Save the graphic representation of the tree into an image file
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png("RothkoTree.png")

# Display the tree
graph = graphviz.Source(dot_data)  
graph

# %%
ada_discrete = AdaBoostClassifier(
    base_estimator=clf,
    learning_rate=1,
    n_estimators=400,
    algorithm='SAMME'
)

# %%
ada_discrete.fit(features_train, target_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1, n_estimators=400, random_state=None)

# %%
# Score the model on the training data
clf.score(features_train, target_train)
# Out:
# 1.0

# %%
ada_discrete.score(features_train, target_train)
# Out:
# 1.0

# %%
# Predict the bins for the test data
p = clf.predict(features_test)
for i in range(0, len(p)):
    print(p[i] == target_test.tolist()[i], p[i], target_test.tolist()[i])
# Out:
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1947, 1950] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1935, 1940] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1968, 1971] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1935, 1940]
# False (1940, 1947] (1935, 1940]
# False (1947, 1950] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# False (1968, 1971] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1968, 1971] (1968, 1971]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1935, 1940] (1935, 1940]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]

# %%
# Score the model on the test data
clf.score(features_test, target_test)
# Out:
# 0.7857142857142857

# %%
# Check the accuracy score for the predicted values
sklearn.metrics.accuracy_score(target_test,p)
# Out:
# 0.7857142857142857

# %%
# # Save the model to a file
# filename = "RothkoDecisionTree.pkl"
# pickle.dump(clf, open(filename, "wb"))

# %%
# # load the model from disk
# loaded_clf = pickle.load(open(filename, "rb"))

# %%
# loaded_clf.score(features_test, target_test)
# Out:
# 0.7857142857142857

# %% [markdown]
# ## ADABOOST

# %%
from sklearn import tree
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import graphviz 
import pydotplus
import sklearn
import pickle

# For AdaBoost
from sklearn.ensemble import AdaBoostClassifier

# %%
data = pd.DataFrame.from_csv('../../data/data.csv')
# Out:
# /Users/acanois/anaconda2/envs/lab/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   if __name__ == '__main__':

# %%
data = data[['year','shannon_entropy','mean_color_r','luminance','contrast', 'contour']]

# %%
# Bin the data into appropriate art timelines for the artist
bins = [1935, 1940, 1947, 1950, 1968, 1971]
data['year_bin']=pd.cut(data['year'], bins)

# %%
# Create the Decision Tree Classifier
clf = tree.DecisionTreeClassifier()

# %%
# Split the columns to separate the features from the result/target data
features = data[['shannon_entropy','mean_color_r','luminance','contrast', 'contour']]
target = data['year_bin'].astype(str)

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features, target, random_state=41)

# %%
# Train the model
clf.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
ada_real = AdaBoostClassifier(
    base_estimator=clf,
    learning_rate=1,
    n_estimators=4000,
    algorithm='SAMME.R'
)

# %%
ada_real.fit(features_train, target_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1, n_estimators=4000, random_state=None)

# %%
# Score the model on the training data
clf.score(features_train, target_train)
# Out:
# 1.0

# %%
ada_real.score(features_train, target_train)
# Out:
# 1.0

# %%
tree_predict = clf.predict(features_test)
for i in range(0, len(tree_predict)):
    print(tree_predict[i] == target_test.tolist()[i], tree_predict[i], target_test.tolist()[i])
# Out:
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1947, 1950] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1935, 1940]
# False (1940, 1947] (1935, 1940]
# False (1947, 1950] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# False (1940, 1947] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1968, 1971] (1968, 1971]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# False (1947, 1950] (1940, 1947]
# True (1935, 1940] (1935, 1940]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]

# %%
ada_predict = ada_real.predict(features_test)
for i in range(0, len(ada_predict)):
    print(ada_predict[i] == target_test.tolist()[i], ada_predict[i], target_test.tolist()[i])
# Out:
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1947, 1950] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1935, 1940] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1935, 1940]
# False (1940, 1947] (1935, 1940]
# False (1947, 1950] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# False (1968, 1971] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1968, 1971] (1968, 1971]
# False (1968, 1971] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1940, 1947] (1940, 1947]
# True (1935, 1940] (1935, 1940]
# True (1940, 1947] (1940, 1947]
# True (1950, 1968] (1950, 1968]
# True (1947, 1950] (1947, 1950]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# True (1950, 1968] (1950, 1968]
# False (1950, 1968] (1947, 1950]
# True (1940, 1947] (1940, 1947]
# False (1947, 1950] (1950, 1968]

# %%
# Check the accuracy score for the decision tree values
sklearn.metrics.accuracy_score(target_test, tree_predict)
# Out:
# 0.8095238095238095

# %%
# Check the accuracy score for the adaboosted values
sklearn.metrics.accuracy_score(target_test, ada_predict)
# Out:
# 0.7380952380952381

# %% [markdown]
# ## Save Adaboosted Model

# %%
# Save the model to a file
filename = "RothkoDecisionTree.pkl"
pickle.dump(clf, open(filename, "wb"))

# %%
# load the model from disk
loaded_clf = pickle.load(open(filename, "rb"))

# %%
loaded_clf.score(features_test, target_test)
# Out:
# 0.8095238095238095
