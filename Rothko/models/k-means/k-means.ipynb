# %%
from sklearn.datasets.samples_generator import make_blobs
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
data = pd.DataFrame.from_csv('../../data/data.csv')

# %%
data = data[['year','shannon_entropy','mean_color_r','luminance','contrast', 'contour']]

# %%
data.plot(kind='scatter', x='year', y='contour', c='mean_color_r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1367f15e5c61> in <module>()
#       1 data.plot(kind='scatter', x='year', y='contour', c='mean_color_r')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from sklearn.model_selection import train_test_split

features = data[['shannon_entropy','mean_color_r','luminance','contrast', 'contour']]
target = data['year']
features_train, features_test, target_train, target_test = train_test_split(features, target, random_state=41)

# %%
pca=PCA(n_components=2)
pca_features = pca.fit_transform(features)

# %%
df =pd.DataFrame({'pca_feature_1':[x[0] for x in pca_features],\
                  'pca_feature_2':[x[1] for x in pca_features], 'year':list(target.values)})

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['pca_feature_2'], y=df['pca_feature_1'], c=(df['year']-1936))

# %%
plt.show()
