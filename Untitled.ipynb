# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.filters import sobel
from skimage.measure import label
from skimage.segmentation import slic, join_segmentations
from skimage.morphology import watershed, binary_erosion, erosion
from skimage.color import label2rgb
from skimage import data
from skimage import io

# %%
img = io.imread('images/wikiart/1961_1.jpg', as_gray=True)

# %%
edges = sobel(img)

# %%
# Identify some background and foreground pixels from the intensity values.
# These pixels are used as seeds for watershed.
markers = np.zeros_like(img)
foreground, background = 1, 2
markers[img < 30.0] = background
markers[img > 150.0] = foreground

ws = watershed(edges, markers)
seg1 = label(ws == foreground)

# Make segmentation using SLIC superpixels.
seg2 = slic(img, n_segments=11, max_iter=160, sigma=1, compactness=0.75,
            multichannel=False)

# Combine the two.
segj = join_segmentations(seg1, seg2)

# Show the segmentations.
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(9, 5),
                         sharex=True, sharey=True)
ax = axes.ravel()
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Image')

color1 = label2rgb(seg1, image=img, bg_label=0)
ax[1].imshow(color1)
ax[1].set_title('Sobel+Watershed')

color2 = label2rgb(seg2, image=img, image_alpha=0.5)
ax[2].imshow(color2)
ax[2].set_title('SLIC superpixels')

color3 = label2rgb(segj, image=img, image_alpha=0.5)
ax[3].imshow(color3)
ax[3].set_title('Join')

for a in ax:
    a.axis('off')
fig.tight_layout()
plt.show()

# %%
from skimage import exposure
from skimage.filters import rank
from skimage.morphology import disk

# %%
noisy_image = io.imread('images/wikiart/1936_1.jpg', as_gray=True)

# %%
# equalize globally and locally
glob = exposure.equalize_hist(noisy_image) * 255
loc = rank.equalize(noisy_image, disk(20))
# Out:
# /Users/acanois/anaconda2/envs/lab/lib/python3.6/site-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# extract histogram for each image
hist = np.histogram(noisy_image, bins=np.arange(0, 256))
glob_hist = np.histogram(glob, bins=np.arange(0, 256))
loc_hist = np.histogram(loc, bins=np.arange(0, 256))

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 12))
ax = axes.ravel()

ax[0].imshow(noisy_image, interpolation='nearest', cmap=plt.cm.gray)
ax[0].axis('off')

ax[1].plot(hist[1][:-1], hist[0], lw=2)
ax[1].set_title('Histogram of gray values')

ax[2].imshow(glob, interpolation='nearest', cmap=plt.cm.gray)
ax[2].axis('off')

ax[3].plot(glob_hist[1][:-1], glob_hist[0], lw=2)
ax[3].set_title('Histogram of gray values')

ax[4].imshow(loc, interpolation='nearest', cmap=plt.cm.gray)
ax[4].axis('off')

ax[5].plot(loc_hist[1][:-1], loc_hist[0], lw=2)
ax[5].set_title('Histogram of gray values')

plt.tight_layout()

# %%
io.imshow(glob, interpolation='nearest', cmap=plt.cm.gray)
# Out:
# /Users/acanois/anaconda2/envs/lab/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:80: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "

# %%
from skimage.measure import perimeter
from skimage.util import invert

# %%
io.imshow(erosion(loc))

# %%
from skimage.measure import find_contours

# %%
contours = perimeter(glob)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-6f0e33de2d5a> in <module>()
# ----> 1 contours = perimeter(glob)
#
# ~/anaconda2/envs/lab/lib/python3.6/site-packages/skimage/measure/_regionprops.py in perimeter(image, neighbourhood)
#     613     # as much time)
#     614     perimeter_histogram = np.bincount(perimeter_image.ravel(), minlength=50)
# --> 615     total_perimeter = np.dot(perimeter_histogram, perimeter_weights)
#     616     return total_perimeter
#     617
#
# ValueError: shapes (256,) and (50,) not aligned: 256 (dim 0) != 50 (dim 0)

# %%
# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(glob, interpolation='nearest', cmap=plt.cm.gray)

for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
