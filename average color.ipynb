# %%
import skimage
from skimage import data
from skimage import io
import numpy as np

# %%
img=io.imread('Rothko_AI/1970_1.jpg')

# %%
flat_img=[]
for x in img:
    for y in x:
        flat_img.append(y)

# %%
r = np.array([x[0] for x in flat_img]).mean()
g = np.array([x[1] for x in flat_img]).mean()
b = np.array([x[2] for x in flat_img]).mean()
rgb=[r,g,b]

# %%
rgb
# Out:
# [94.2778710691824, 75.42661006289308, 94.42837735849056]

# %%
skimage.external.tifffile.imshow(img)
import matplotlib.pyplot as plt
plt.show()
