# %%
import skimage
from skimage import data
from skimage import io
import numpy as np
import pandas as pd
import os

# %%
def mode_color(img):
    #read in image
    img=io.imread(img)
    #flatten image
    flat_img=[]
    for x in img:
        for y in x:
            flat_img.append(y)
    #convert pixels to strings
    flat_img=[str(x) for x in flat_img]
    #create dictionary with pixel color counts
    counts = {}
    for i in flat_img:
        if i in counts:
            counts[i] += 1
        else:
            counts[i] = 1
    #find maximum value and convert to numpy array
    key_max = max(counts.keys(), key=(lambda k: counts[k]))
    key_max=key_max.split('[')[1].split(']')[0]
    rgb=np.fromstring(key_max, dtype=int, sep=' ')
    rgb=[rgb[0],rgb[1],rgb[2]]
    return rgb

def mean_color(img):
    #read in image
    img=io.imread(img)
    #flatten image
    flat_img=[]
    for x in img:
        for y in x:
            flat_img.append(y)
    #calculate mean red, green and blue
    r = np.array([x[0] for x in flat_img]).mean()
    g = np.array([x[1] for x in flat_img]).mean()
    b = np.array([x[2] for x in flat_img]).mean()
    #combine into one array
    rgb=[r,g,b]
    return rgb

def shannon_entropy(img):
    #ready-made method
    entropy = skimage.measure.shannon_entropy(io.imread(img), base=2)
    return entropy

# %%
data_ = {'file_name':[], 'year':[], 'mode_color':[], 'mode_color_r':[], 'mode_color_g':[],\
         'mode_color_b':[], 'mean_color':[], 'mean_color_r':[], 'mean_color_g':[], 'mean_color_b':[],\
         'shannon_entropy':[]}
for dirpath, subdirs, files in os.walk('../images', topdown=False):
    for x in files:
        if '.jpg' in x:
            filename = os.path.join(dirpath, x)
            data_['file_name'].append(filename)
            data_['year'].append(filename.split('_')[0])
            rgb = mode_color(filename)
            data_['mode_color'].append(rgb)
            data_['mode_color_r'].append(rgb[0])
            data_['mode_color_g'].append(rgb[1])
            data_['mode_color_b'].append(rgb[2])
            rgb = mean_color(filename)        
            data_['mean_color'].append(rgb)
            data_['mean_color_r'].append(rgb[0])
            data_['mean_color_g'].append(rgb[1])
            data_['mean_color_b'].append(rgb[2])
            data_['shannon_entropy'].append(shannon_entropy(filename))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-0bd05e0ae8d0> in <module>()
#       3     count=0
#       4     for name in dirs:
# ----> 5         for filename in files[count]:
#       6             if '.jpg' in filename:
#       7                 filename=name+'/'+filename
#
# IndexError: list index out of range

# %%
df=pd.DataFrame(data_)

# %%
df.to_csv('../data/data.csv')

# %%
for root, dirs, files in os.walk('../images', topdown=False):
    print(files[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-d55feea54d6f> in <module>()
#       1 for root, dirs, files in os.walk('../images', topdown=False):
# ----> 2     print(files[2])
#
# IndexError: list index out of range

# %%
for dirpath, subdirs, files in os.walk('../images', topdown=False):
    for x in files:
        if '.jpg' in x:
            filename = os.path.join(dirpath, x)
            print(filename)
# Out:
# ../images/Rothko_guggenheim_org/1946_31.jpg
# ../images/Rothko_guggenheim_org/1953_31.jpg
# ../images/Rothko_moma/1944_41.jpg
# ../images/Rothko_moma/1951_41.jpg
# ../images/Rothko_moma/1949_41.jpg
# ../images/Rothko_moma/1945_41.jpg
# ../images/wikiart/1967_1.jpg
# ../images/wikiart/1961_7.jpg
# ../images/wikiart/1945_6.jpg
# ../images/wikiart/1958_3.jpg
# ../images/wikiart/1958_2.jpg
# ../images/wikiart/1945_7.jpg
# ../images/wikiart/1961_6.jpg
# ../images/wikiart/1967_2.jpg
# ../images/wikiart/1961_4.jpg
# ../images/wikiart/1949_8.jpg
# ../images/wikiart/1939_1.jpg
# ../images/wikiart/1945_5.jpg
# ../images/wikiart/1958_1.jpg
# ../images/wikiart/1945_4.jpg
# ../images/wikiart/1949_9.jpg
# ../images/wikiart/1961_5.jpg
# ../images/wikiart/1947_2.jpg
# ../images/wikiart/1961_1.jpg
# ../images/wikiart/1958_5.jpg
# ../images/wikiart/1958_4.jpg
# ../images/wikiart/1945_1.jpg
# ../images/wikiart/1947_3.jpg
# ../images/wikiart/1961_2.jpg
# ../images/wikiart/1947_1.jpg
# ../images/wikiart/1945_3.jpg
# ../images/wikiart/1958_6.jpg
# ../images/wikiart/1945_2.jpg
# ../images/wikiart/1963_1.jpg
# ../images/wikiart/1961_3.jpg
# ../images/wikiart/1944_5.jpg
# ../images/wikiart/1938_1.jpg
# ../images/wikiart/1948_8.jpg
# ../images/wikiart/1940_1.jpg
# ../images/wikiart/1942_3.jpg
# ../images/wikiart/1942_2.jpg
# ../images/wikiart/1964_1.jpg
# ../images/wikiart/1948_9.jpg
# ../images/wikiart/1959_1.jpg
# ../images/wikiart/1944_4.jpg
# ../images/wikiart/1944_6.jpg
# ../images/wikiart/1959_3.jpg
# ../images/wikiart/1938_2.jpg
# ../images/wikiart/1940_2.jpg
# ../images/wikiart/1966_1.jpg
# ../images/wikiart/1964_3.jpg
# ../images/wikiart/1964_2.jpg
# ../images/wikiart/1942_1.jpg
# ../images/wikiart/1938_3.jpg
# ../images/wikiart/1959_2.jpg
# ../images/wikiart/1962_4.jpg
# ../images/wikiart/1957_9.jpg
# ../images/wikiart/1944_3.jpg
# ../images/wikiart/1959_6.jpg
# ../images/wikiart/1960_2.jpg
# ../images/wikiart/1946_1.jpg
# ../images/wikiart/1942_5.jpg
# ../images/wikiart/1964_6.jpg
# ../images/wikiart/1942_4.jpg
# ../images/wikiart/1960_3.jpg
# ../images/wikiart/1959_7.jpg
# ../images/wikiart/1944_2.jpg
# ../images/wikiart/1962_1.jpg
# ../images/wikiart/1957_8.jpg
# ../images/wikiart/1962_3.jpg
# ../images/wikiart/1957_11.jpg
# ../images/wikiart/1959_5.jpg
# ../images/wikiart/1946_2.jpg
# ../images/wikiart/1960_1.jpg
# ../images/wikiart/1968_8.jpg
# ../images/wikiart/1964_5.jpg
# ../images/wikiart/1964_4.jpg
# ../images/wikiart/1959_4.jpg
# ../images/wikiart/1957_10.jpg
# ../images/wikiart/1962_2.jpg
# ../images/wikiart/1944_1.jpg
# ../images/wikiart/1957_6.jpg
# ../images/wikiart/1955_4.jpg
# ../images/wikiart/1948_1.jpg
# ../images/wikiart/1953_2.jpg
# ../images/wikiart/1968_4.jpg
# ../images/wikiart/1951_1.jpg
# ../images/wikiart/1968_5.jpg
# ../images/wikiart/1953_3.jpg
# ../images/wikiart/1957_7.jpg
# ../images/wikiart/1957_5.jpg
# ../images/wikiart/1948_2.jpg
# ../images/wikiart/1953_1.jpg
# ../images/wikiart/1968_7.jpg
# ../images/wikiart/1951_2.jpg
# ../images/wikiart/1968_6.jpg
# ../images/wikiart/1948_3.jpg
# ../images/wikiart/1957_4.jpg
# ../images/wikiart/1936_1.jpg
# ../images/wikiart/1955_2.jpg
# ../images/wikiart/1948_7.jpg
# ../images/wikiart/1953_4.jpg
# ../images/wikiart/1968_2.jpg
# ../images/wikiart/1968_3.jpg
# ../images/wikiart/1953_5.jpg
# ../images/wikiart/1948_6.jpg
# ../images/wikiart/1955_3.jpg
# ../images/wikiart/1957_1.jpg
# ../images/wikiart/1957_3.jpg
# ../images/wikiart/1955_1.jpg
# ../images/wikiart/1936_2.jpg
# ../images/wikiart/1948_4.jpg
# ../images/wikiart/1953_7.jpg
# ../images/wikiart/1968_1.jpg
# ../images/wikiart/1953_6.jpg
# ../images/wikiart/1948_5.jpg
# ../images/wikiart/1936_3.jpg
# ../images/wikiart/1957_2.jpg
# ../images/wikiart/1950_3.jpg
# ../images/wikiart/1952_1.jpg
# ../images/wikiart/1969_7.jpg
# ../images/wikiart/1954_7.jpg
# ../images/wikiart/1949_2.jpg
# ../images/wikiart/1956_4.jpg
# ../images/wikiart/1949_3.jpg
# ../images/wikiart/1954_6.jpg
# ../images/wikiart/1969_6.jpg
# ../images/wikiart/1950_2.jpg
# ../images/wikiart/1952_2.jpg
# ../images/wikiart/1969_4.jpg
# ../images/wikiart/1954_4.jpg
# ../images/wikiart/1949_1.jpg
# ../images/wikiart/1954_5.jpg
# ../images/wikiart/1969_5.jpg
# ../images/wikiart/1952_3.jpg
# ../images/wikiart/1950_1.jpg
# ../images/wikiart/1969_1.jpg
# ../images/wikiart/1954_1.jpg
# ../images/wikiart/1937_2.jpg
# ../images/wikiart/1949_4.jpg
# ../images/wikiart/1956_3.jpg
# ../images/wikiart/1970_1.jpg
# ../images/wikiart/1956_2.jpg
# ../images/wikiart/1949_5.jpg
# ../images/wikiart/1950_4.jpg
# ../images/wikiart/1952_4.jpg
# ../images/wikiart/1969_2.jpg
# ../images/wikiart/1937_1.jpg
# ../images/wikiart/1954_2.jpg
# ../images/wikiart/1949_7.jpg
# ../images/wikiart/1956_1.jpg
# ../images/wikiart/1970_2.jpg
# ../images/wikiart/1949_6.jpg
# ../images/wikiart/1954_3.jpg
# ../images/wikiart/1969_3.jpg
# ../images/mark_rothko_org/1969_11.jpg
# ../images/mark_rothko_org/1955_11.jpg
# ../images/mark_rothko_org/1957_12.jpg
# ../images/mark_rothko_org/1961_11.jpg
# ../images/mark_rothko_org/1964_11.jpg
# ../images/mark_rothko_org/1957-11.jpg
# ../images/mark_rothko_org/1958_11.jpg
# ../images/Rothko_nga_gov/1969_12.jpg
# ../images/Rothko_nga_gov/1969_11.jpg
# ../images/Rothko_nga_gov/1953_11.jpg
# ../images/Rothko_nga_gov/1959_11.jpg
# ../images/Rothko_nga_gov/1964_11.jpg
# ../images/Rothko_nga_gov/1968_11.jpg
