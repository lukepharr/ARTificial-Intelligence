# %%
import skimage
from skimage import data
from skimage import io
import numpy as np
import pandas as pd
import os

# %%
def mode_color(img):
    #read in image
    img=io.imread(img)
    #flatten image
    flat_img=[]
    for x in img:
        for y in x:
            flat_img.append(y)
    #convert pixels to strings
    flat_img=[str(x) for x in flat_img]
    #create dictionary with pixel color counts
    counts = {}
    for i in flat_img:
        if i in counts:
            counts[i] += 1
        else:
            counts[i] = 1
    #find maximum value and convert to numpy array
    key_max = max(counts.keys(), key=(lambda k: counts[k]))
    key_max=key_max.split('[')[1].split(']')[0]
    rgb=np.fromstring(key_max, dtype=int, sep=' ')
    rgb=[rgb[0],rgb[1],rgb[2]]
    return rgb

def mean_color(img):
    #read in image
    img=io.imread(img)
    #flatten image
    flat_img=[]
    for x in img:
        for y in x:
            flat_img.append(y)
    #calculate mean red, green and blue
    r = np.array([x[0] for x in flat_img]).mean()
    g = np.array([x[1] for x in flat_img]).mean()
    b = np.array([x[2] for x in flat_img]).mean()
    #combine into one array
    rgb=[r,g,b]
    return rgb

def shannon_entropy(img):
    #ready-made method
    entropy = skimage.measure.shannon_entropy(io.imread(img), base=2)
    return entropy

# %%
data_ = {'file_name':[], 'year':[], 'mode_color':[], 'mode_color_r':[], 'mode_color_g':[],\
         'mode_color_b':[], 'mean_color':[], 'mean_color_r':[], 'mean_color_g':[], 'mean_color_b':[],\
         'shannon_entropy':[]}
for dirpath, subdirs, files in os.walk('../images', topdown=False):
    for x in files:
        if '.jpg' in x:
            filename = os.path.join(dirpath, x)
            data_['file_name'].append(filename)
            data_['year'].append(x.split('_')[0])
            rgb = mode_color(filename)
            data_['mode_color'].append(rgb)
            data_['mode_color_r'].append(rgb[0])
            data_['mode_color_g'].append(rgb[1])
            data_['mode_color_b'].append(rgb[2])
            rgb = mean_color(filename)        
            data_['mean_color'].append(rgb)
            data_['mean_color_r'].append(rgb[0])
            data_['mean_color_g'].append(rgb[1])
            data_['mean_color_b'].append(rgb[2])
            data_['shannon_entropy'].append(shannon_entropy(filename))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-e6a6655d7080> in <module>()
#       6             data_['file_name'].append(filename)
#       7             data_['year'].append(x.split('_')[0])
# ----> 8             rgb = mode_color(filename)
#       9             data_['mode_color'].append(rgb)
#      10             data_['mode_color_r'].append(rgb[0])
#
# <ipython-input-64-7652f4317ce2> in mode_color(img)
#       9             flat_img.append(y)
#      10     #convert pixels to strings
# ---> 11     flat_img=[str(x) for x in flat_img]
#      12     #create dictionary with pixel color counts
#      13     counts = {}
#
# <ipython-input-64-7652f4317ce2> in <listcomp>(.0)
#       9             flat_img.append(y)
#      10     #convert pixels to strings
# ---> 11     flat_img=[str(x) for x in flat_img]
#      12     #create dictionary with pixel color counts
#      13     counts = {}
#
# /Users/Luke/anaconda/lib/python3.6/site-packages/numpy/core/arrayprint.py in array_str(a, max_line_width, precision, suppress_small)
#    1465         return _guarded_str(np.ndarray.__getitem__(a, ()))
#    1466
# -> 1467     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1468
#    1469 def set_string_function(f, repr=True):
#
# /Users/Luke/anaconda/lib/python3.6/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, **kwarg)
#     631         return "[]"
#     632
# --> 633     return _array2string(a, options, separator, prefix)
#     634
#     635
#
# KeyboardInterrupt:

# %%
df=pd.DataFrame(data_)

# %%
df.to_csv('../data/data.csv')

# %%
# Out:
#                                        file_name  \
# 0    ../images/Rothko_guggenheim_org/1946_31.jpg
# 1    ../images/Rothko_guggenheim_org/1953_31.jpg
# 2              ../images/Rothko_moma/1944_41.jpg
# 3              ../images/Rothko_moma/1951_41.jpg
# 4              ../images/Rothko_moma/1949_41.jpg
# 5              ../images/Rothko_moma/1945_41.jpg
# 6                   ../images/wikiart/1967_1.jpg
# 7                   ../images/wikiart/1961_7.jpg
# 8                   ../images/wikiart/1945_6.jpg
# 9                   ../images/wikiart/1958_3.jpg
# 10                  ../images/wikiart/1958_2.jpg
# 11                  ../images/wikiart/1945_7.jpg
# 12                  ../images/wikiart/1961_6.jpg
# 13                  ../images/wikiart/1967_2.jpg
# 14                  ../images/wikiart/1961_4.jpg
# 15                  ../images/wikiart/1949_8.jpg
# 16                  ../images/wikiart/1939_1.jpg
# 17                  ../images/wikiart/1945_5.jpg
# 18                  ../images/wikiart/1958_1.jpg
# 19                  ../images/wikiart/1945_4.jpg
# 20                  ../images/wikiart/1949_9.jpg
# 21                  ../images/wikiart/1961_5.jpg
# 22                  ../images/wikiart/1947_2.jpg
# 23                  ../images/wikiart/1961_1.jpg
# 24                  ../images/wikiart/1958_5.jpg
# 25                  ../images/wikiart/1958_4.jpg
# 26                  ../images/wikiart/1945_1.jpg
# 27                  ../images/wikiart/1947_3.jpg
# 28                  ../images/wikiart/1961_2.jpg
# 29                  ../images/wikiart/1947_1.jpg
# ..                                           ...
# 138                 ../images/wikiart/1937_2.jpg
# 139                 ../images/wikiart/1949_4.jpg
# 140                 ../images/wikiart/1956_3.jpg
# 141                 ../images/wikiart/1970_1.jpg
# 142                 ../images/wikiart/1956_2.jpg
# 143                 ../images/wikiart/1949_5.jpg
# 144                 ../images/wikiart/1950_4.jpg
# 145                 ../images/wikiart/1952_4.jpg
# 146                 ../images/wikiart/1969_2.jpg
# 147                 ../images/wikiart/1937_1.jpg
# 148                 ../images/wikiart/1954_2.jpg
# 149                 ../images/wikiart/1949_7.jpg
# 150                 ../images/wikiart/1956_1.jpg
# 151                 ../images/wikiart/1970_2.jpg
# 152                 ../images/wikiart/1949_6.jpg
# 153                 ../images/wikiart/1954_3.jpg
# 154                 ../images/wikiart/1969_3.jpg
# 155        ../images/mark_rothko_org/1969_11.jpg
# 156        ../images/mark_rothko_org/1955_11.jpg
# 157        ../images/mark_rothko_org/1957_12.jpg
# 158        ../images/mark_rothko_org/1961_11.jpg
# 159        ../images/mark_rothko_org/1964_11.jpg
# 160        ../images/mark_rothko_org/1957-11.jpg
# 161        ../images/mark_rothko_org/1958_11.jpg
# 162         ../images/Rothko_nga_gov/1969_12.jpg
# 163         ../images/Rothko_nga_gov/1969_11.jpg
# 164         ../images/Rothko_nga_gov/1953_11.jpg
# 165         ../images/Rothko_nga_gov/1959_11.jpg
# 166         ../images/Rothko_nga_gov/1964_11.jpg
# 167         ../images/Rothko_nga_gov/1968_11.jpg
#
#                                             mean_color  mean_color_b  \
# 0    [195.04633161367624, 179.93297130025903, 160.4...    160.439238
# 1    [228.9834626679892, 156.9777388801369, 10.6742...     10.674273
# 2    [217.90556421172752, 214.52938465589887, 205.0...    205.071415
# 3    [191.22959893724698, 183.47946451163966, 168.9...    168.976993
# 157     57.138869    157.265576    [255, 68, 33]            33            68
# 158     66.690646    219.142465     [249, 73, 0]             0            73
# 159     59.772751     70.463777     [58, 57, 65]            65            57
# 160    104.310234    201.828000    [188, 19, 42]            42            19
# 161     76.934079    107.672472    [105, 77, 65]            65            77
# 162    172.836729    170.972241  [160, 166, 166]           166           166
# 163     96.310514    119.625754  [222, 222, 212]           212           222
# 164     43.543232    116.631459        [0, 0, 0]             0             0
# 165     70.477506    166.851098    [109, 58, 57]            57            58
# 166     42.179898     53.924029     [49, 43, 43]            43            43
# 167     15.376657     32.056846       [16, 1, 6]             6             1
#
#      mode_color_r  shannon_entropy                    year
# 0             204         6.768127        ../images/Rothko
# 1             251         6.937948        ../images/Rothko
# 2             243         6.519651        ../images/Rothko
# 3             247         6.451747        ../images/Rothko
# 4             237         5.738259        ../images/Rothko
# 5             104         6.255055        ../images/Rothko
# 6             169         6.584765  ../images/wikiart/1967
# 7             193         6.084142  ../images/wikiart/1961
# 8             246         7.585441  ../images/wikiart/1945
# 9              84         6.670086  ../images/wikiart/1958
# 10             32         4.127101  ../images/wikiart/1958
# 11            125         7.466985  ../images/wikiart/1945
# 12            139         6.547524  ../images/wikiart/1961
# 13             11         6.540725  ../images/wikiart/1967
# 14            202         6.482552  ../images/wikiart/1961
# 15             62         7.247863  ../images/wikiart/1949
# 16            220         7.844444  ../images/wikiart/1939
# 17            227         7.664053  ../images/wikiart/1945
# 18             36         5.492563  ../images/wikiart/1958
# 19             59         7.577653  ../images/wikiart/1945
# 20            237         7.604876  ../images/wikiart/1949
# 21             50         5.767700  ../images/wikiart/1961
# 22            163         7.386364  ../images/wikiart/1947
# 23            224         7.241842  ../images/wikiart/1961
# 24             23         6.680274  ../images/wikiart/1958
# 25             87         5.915477  ../images/wikiart/1958
# 26            227         7.369926  ../images/wikiart/1945
# 27            194         7.357760  ../images/wikiart/1947
# 28             91         6.012707  ../images/wikiart/1961
# 29            172         7.694028  ../images/wikiart/1947
# ..            ...              ...                     ...
# 138           215         7.834380  ../images/wikiart/1937
# 139            58         6.858416  ../images/wikiart/1949
# 140           182         6.946845  ../images/wikiart/1956
# 141            48         6.514046  ../images/wikiart/1970
# 142           244         6.940110  ../images/wikiart/1956
# 143           254         7.809270  ../images/wikiart/1949
# 144           248         7.423524  ../images/wikiart/1950
# 145            66         6.494997  ../images/wikiart/1952
# 146            60         6.090644  ../images/wikiart/1969
# 147           189         7.497206  ../images/wikiart/1937
# 148           254         7.578142  ../images/wikiart/1954
# 149            37         7.219228  ../images/wikiart/1949
# 150           231         6.733142  ../images/wikiart/1956
# 151           197         6.154542  ../images/wikiart/1970
# 152           250         7.423689  ../images/wikiart/1949
# 153           210         7.126815  ../images/wikiart/1954
# 154             1         4.018994  ../images/wikiart/1969
# 155            30         6.564855          ../images/mark
# 156           210         7.182303          ../images/mark
# 157           255         6.613272          ../images/mark
# 158           249         6.887675          ../images/mark
# 159            58         5.361521          ../images/mark
# 160           188         7.211815          ../images/mark
# 161           105         5.870524          ../images/mark
# 162           160         6.390406        ../images/Rothko
# 163           222         7.539843        ../images/Rothko
# 164             0         5.300447        ../images/Rothko
# 165           109         6.340608        ../images/Rothko
# 166            49         4.593521        ../images/Rothko
# 167            16         5.522483        ../images/Rothko
#
# [168 rows x 11 columns]
